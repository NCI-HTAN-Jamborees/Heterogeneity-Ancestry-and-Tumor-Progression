# %%
import os
import pandas as pd

# %% [markdown]
# #### Load metadata file for all cases for the Vanderbilt dataset

# %%
caseDF = pd.read_csv("metadata/cases.tsv", sep="\t")
caseDF = caseDF[["HTAN Participant ID", "Atlas Name", "Age at Diagnosis (years)", "Year Of Birth", "Race", "Gender", "Ethnicity", "Vital Status"]]
caseDF.head()
# Out:
#   HTAN Participant ID       Atlas Name  Age at Diagnosis (years)  \
# 0           HTA11_347  HTAN Vanderbilt                         0
# 1            HTA11_78  HTAN Vanderbilt                         0
# 2           HTA11_696  HTAN Vanderbilt                         0
# 3            HTA11_83  HTAN Vanderbilt                         0
# 4           HTA11_104  HTAN Vanderbilt                         0
#
#    Year Of Birth                       Race  Gender               Ethnicity  \
# 0         1959.0                      Other  female  not hispanic or latino
# 1         1952.0                      white    male  not hispanic or latino
# 2         1969.0                      white    male  not hispanic or latino
# 3         1955.0  black or african american    male  not hispanic or latino
# 4         1965.0                      white    male  not hispanic or latino
#
#   Vital Status
# 0        Alive
# 1        Alive
# 2        Alive
# 3        Alive
# 4        Alive

# %% [markdown]
# #### Load metadata file for all biospeciemens for the Vanderbilt dataset

# %%
bioDF = pd.read_csv("metadata/biospecimens.tsv", sep="\t")
bioDF = bioDF[["HTAN Parent ID", "HTAN Biospecimen ID", "Collection Days from Index", "Storage Method", "Processing Days from Index", "Preservation Method", "Tumor Tissue Type"]]
bioDF.head()
# Out:
#   HTAN Parent ID   HTAN Biospecimen ID  Collection Days from Index  \
# 0      HTA11_347  HTA11_347_2000001011                       21802
# 1       HTA11_78   HTA11_78_2000001011                       24370
# 2      HTA11_696  HTA11_696_2000002011                       18342
# 3      HTA11_696  HTA11_696_2000002021                       18342
# 4       HTA11_83   HTA11_83_2000001011                       23394
#
#   Storage Method  Processing Days from Index Preservation Method  \
# 0          Fresh                       21802               Fresh
# 1          Fresh                       24370               Fresh
# 2          Fresh                       18342               Fresh
# 3          Fresh                       18342               Fresh
# 4          Fresh                       23394               Fresh
#
#       Tumor Tissue Type
# 0          Premalignant
# 1          Premalignant
# 2                Normal
# 3                Normal
# 4  Atypia - hyperplasia

# %% [markdown]
# #### Mapping each biospecimen to a patient

# %%
caseBioDF = pd.merge(caseDF, bioDF, left_on="HTAN Participant ID", right_on="HTAN Parent ID", how="outer")
caseBioDF.head()
# Out:
#   HTAN Participant ID       Atlas Name  Age at Diagnosis (years)  \
# 0           HTA11_347  HTAN Vanderbilt                         0
# 1           HTA11_347  HTAN Vanderbilt                         0
# 2            HTA11_78  HTAN Vanderbilt                         0
# 3            HTA11_78  HTAN Vanderbilt                         0
# 4            HTA11_78  HTAN Vanderbilt                         0
#
#    Year Of Birth   Race  Gender               Ethnicity Vital Status  \
# 0         1959.0  Other  female  not hispanic or latino        Alive
# 1         1959.0  Other  female  not hispanic or latino        Alive
# 2         1952.0  white    male  not hispanic or latino        Alive
# 3         1952.0  white    male  not hispanic or latino        Alive
# 4         1952.0  white    male  not hispanic or latino        Alive
#
#   HTAN Parent ID   HTAN Biospecimen ID  Collection Days from Index  \
# 0      HTA11_347  HTA11_347_2000001011                       21802
# 1      HTA11_347  HTA11_347_2000009901                       21802
# 2       HTA11_78   HTA11_78_2000001011                       24370
# 3       HTA11_78   HTA11_78_2000002011                       24370
# 4       HTA11_78   HTA11_78_2000009901                       24370
#
#    Storage Method  Processing Days from Index Preservation Method  \
# 0           Fresh                       21802               Fresh
# 1  Frozen at -80C                       21802              Frozen
# 2           Fresh                       24370               Fresh
# 3           Fresh                       24370               Fresh
# 4  Frozen at -80C                       24370              Frozen
#
#          Tumor Tissue Type
# 0             Premalignant
# 1  Not Otherwise Specified
# 2             Premalignant
# 3                   Normal
# 4  Not Otherwise Specified

# %% [markdown]
# #### Load metadata file for the Vanderbilt dataset obtained from bigQuery (provided by Ino). Extract the HTAN_Data_File_ID to match with the biospecimen ID

# %%
queryDF = pd.read_csv("metadata/bigquery_vanderbilt_everything.csv")
queryDF = queryDF[queryDF["Component"].isin(["ScRNA-seqLevel3", "10xVisiumSpatialTranscriptomics-RNA-seqLevel3"])]
bioQuery = queryDF[["HTAN_Data_File_ID", "HTAN_Assayed_Biospecimen_ID"]]

# %% [markdown]
# #### Load the synapse metadata file for scRNA Level3 data

# %%
scDF = pd.read_csv("metadata/syn36266953_ScRNALevel3.csv")
# generate participant ID
scDF["HTAN Participant ID"] = scDF["HTAN Data File ID"].apply(lambda X: "_".join(X.split("_")[0:2]))
# rename the columns
scDF.columns = [f"sc_{X}" for X in scDF.columns] 
# link the biospecimen ID for each sample
scBioDF = pd.merge(scDF, bioQuery, left_on="sc_HTAN Data File ID", right_on="HTAN_Data_File_ID", how="inner")
scBioDF.head()
# Out:
#         sc_Component                                      sc_Filename  \
# 0    ScRNA-seqLevel3           single_cell_RNAseq_level_3/3620as1.csv
# 1    ScRNA-seqLevel3           single_cell_RNAseq_level_3/3620as2.csv
# 2    ScRNA-seqLevel3           single_cell_RNAseq_level_3/3803as1.csv
# 3    ScRNA-seqLevel3           single_cell_RNAseq_level_3/3803as2.csv
# 4    ScRNA-seqLevel3           single_cell_RNAseq_level_3/3882as1.csv
# ..               ...                                              ...
# 305  ScRNA-seqLevel3  single_cell_RNAseq_level_3/7306-YX-7_immune.csv
# 306  ScRNA-seqLevel3     single_cell_RNAseq_level_3/7306-YX-8_epi.csv
# 307  ScRNA-seqLevel3  single_cell_RNAseq_level_3/7306-YX-8_immune.csv
# 308  ScRNA-seqLevel3     single_cell_RNAseq_level_3/7306-YX-9_epi.csv
# 309  ScRNA-seqLevel3  single_cell_RNAseq_level_3/7306-YX-9_immune.csv
#
#     sc_File Format  sc_HTAN Parent Data File ID         sc_HTAN Data File ID  \
# 0              csv    HTA11_347_200000101112111    HTA11_347_200000101113111
# 1              csv     HTA11_78_200000101112111     HTA11_78_200000101113111
# 2              csv    HTA11_696_200000201112111    HTA11_696_200000201113111
# 3              csv    HTA11_696_200000202112111    HTA11_696_200000202113111
# 4              csv     HTA11_83_200000101112111     HTA11_83_200000101113111
# ..             ...                          ...                          ...
# 305            csv  HTA11_13701_200000101112111  HTA11_13701_200000101113112
# 306            csv  HTA11_13701_200000102112111  HTA11_13701_200000102113111
# 307            csv  HTA11_13701_200000102112111  HTA11_13701_200000102113112
# 308            csv  HTA11_13794_200000101112111  HTA11_13794_200000101113111
# 309            csv  HTA11_13794_200000101112111  HTA11_13794_200000101113112
#
#                    sc_Data Category sc_Matrix Type  sc_Linked Matrices  \
# 0    Gene Expression Quantification     Raw Counts                 NaN
# 1    Gene Expression Quantification     Raw Counts                 NaN
# 2    Gene Expression Quantification     Raw Counts                 NaN
# 3    Gene Expression Quantification     Raw Counts                 NaN
# 4    Gene Expression Quantification     Raw Counts                 NaN
# ..                              ...            ...                 ...
# 305  Gene Expression Quantification     Raw Counts                 NaN
# 306  Gene Expression Quantification     Raw Counts                 NaN
# 307  Gene Expression Quantification     Raw Counts                 NaN
# 308  Gene Expression Quantification     Raw Counts                 NaN
# 309  Gene Expression Quantification     Raw Counts                 NaN
#
#      sc_Cell Median Number Reads  sc_Cell Median Number Genes  ...  \
# 0                         9176.0                       2849.0  ...
# 1                         5054.0                       1896.0  ...
# 2                         6112.0                       2293.0  ...
# 3                         6444.0                       2324.0  ...
# 4                        10910.0                       2689.0  ...
# ..                           ...                          ...  ...
# 305                       1753.0                        941.0  ...
# 306                       2654.5                       1193.0  ...
# 307                       1015.0                        653.0  ...
# 308                       3695.0                       1140.0  ...
# 309                        418.5                        336.5  ...
#
#      sc_scRNAseq Workflow Parameters Description  \
# 0        dropkick and QCPipe, default parameters
# 1        dropkick and QCPipe, default parameters
# 2        dropkick and QCPipe, default parameters
# 3        dropkick and QCPipe, default parameters
# 4        dropkick and QCPipe, default parameters
# ..                                           ...
# 305      dropkick and QCPipe, default parameters
# 306      dropkick and QCPipe, default parameters
# 307      dropkick and QCPipe, default parameters
# 308      dropkick and QCPipe, default parameters
# 309      dropkick and QCPipe, default parameters
#
#                                sc_Workflow Link sc_Workflow Version  \
# 0    https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# 1    https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# 2    https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# 3    https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# 4    https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# ..                                          ...                 ...
# 305  https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# 306  https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# 307  https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# 308  https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
# 309  https://github.com/KenLauLab/STAR_Protocol        1.2.2, 1.0.0
#
#      sc_entityId                                 sc_Id  \
# 0    syn23521628  794ac446-4434-40c2-ba37-3c7d1314093e
# 1    syn23521635  e2064be8-393a-4981-972c-2c73889791a8
# 2    syn23521725  2b942a2a-945b-4fc7-b7ae-3529068b379c
# 3    syn23521726  912ea32b-8e17-484d-9775-75a9565212ce
# 4    syn23521727  034225c5-59e0-4adb-af24-fcfad8aedf81
# ..           ...                                   ...
# 305  syn51069173  20fe7008-32ae-4225-b371-ce28f3169a0b
# 306  syn51069094  a1b1c62a-93dd-489d-af2a-8e1d72c38d2e
# 307  syn51069174  31f506d0-2c24-4366-8fbd-f694fa0a5bf6
# 308  syn51069095  a3c4fbe8-4b35-4887-9a46-c54985b45c2b
# 309  syn51069175  90894c2d-f002-4dcc-b88f-488c3bcedf41
#
#     sc_Workflow End Datetime sc_Workflow Start Datetime  \
# 0                   0/0/0000                   0/0/0000
# 1                   0/0/0000                   0/0/0000
# 2                   0/0/0000                   0/0/0000
# 3                   0/0/0000                   0/0/0000
# 4                   0/0/0000                   0/0/0000
# ..                       ...                        ...
# 305                      NaN                        NaN
# 306                      NaN                        NaN
# 307                      NaN                        NaN
# 308                      NaN                        NaN
# 309                      NaN                        NaN
#
#     sc_HTAN Participant ID            HTAN_Data_File_ID  \
# 0                HTA11_347    HTA11_347_200000101113111
# 1                 HTA11_78     HTA11_78_200000101113111
# 2                HTA11_696    HTA11_696_200000201113111
# 3                HTA11_696    HTA11_696_200000202113111
# 4                 HTA11_83     HTA11_83_200000101113111
# ..                     ...                          ...
# 305            HTA11_13701  HTA11_13701_200000101113112
# 306            HTA11_13701  HTA11_13701_200000102113111
# 307            HTA11_13701  HTA11_13701_200000102113112
# 308            HTA11_13794  HTA11_13794_200000101113111
# 309            HTA11_13794  HTA11_13794_200000101113112
#
#     HTAN_Assayed_Biospecimen_ID
# 0          HTA11_347_2000001011
# 1           HTA11_78_2000001011
# 2          HTA11_696_2000002011
# 3          HTA11_696_2000002021
# 4           HTA11_83_2000001011
# ..                          ...
# 305      HTA11_13701_2000001011
# 306      HTA11_13701_2000001021
# 307      HTA11_13701_2000001021
# 308      HTA11_13794_2000001011
# 309      HTA11_13794_2000001011
#
# [310 rows x 22 columns]

# %% [markdown]
# #### merge dataframes to assign biospecimen info to each scRNA file

# %%
scCaseBioDF = pd.merge(scBioDF, caseBioDF, left_on="HTAN_Assayed_Biospecimen_ID", right_on="HTAN Biospecimen ID", how="inner")
scCaseBioDF.to_csv("metadata/scRNA_metadata.csv", index=False)
scCaseBioDF.head()
# Out:
#       sc_Component                             sc_Filename sc_File Format  \
# 0  ScRNA-seqLevel3  single_cell_RNAseq_level_3/3620as1.csv            csv
# 1  ScRNA-seqLevel3  single_cell_RNAseq_level_3/3906as1.csv            csv
# 2  ScRNA-seqLevel3  single_cell_RNAseq_level_3/3620as2.csv            csv
# 3  ScRNA-seqLevel3  single_cell_RNAseq_level_3/3882as4.csv            csv
# 4  ScRNA-seqLevel3  single_cell_RNAseq_level_3/3803as1.csv            csv
#
#   sc_HTAN Parent Data File ID       sc_HTAN Data File ID  \
# 0   HTA11_347_200000101112111  HTA11_347_200000101113111
# 1   HTA11_347_200000101112211  HTA11_347_200000101113211
# 2    HTA11_78_200000101112111   HTA11_78_200000101113111
# 3    HTA11_78_200000101112211   HTA11_78_200000101113211
# 4   HTA11_696_200000201112111  HTA11_696_200000201113111
#
#                  sc_Data Category sc_Matrix Type  sc_Linked Matrices  \
# 0  Gene Expression Quantification     Raw Counts                 NaN
# 1  Gene Expression Quantification     Raw Counts                 NaN
# 2  Gene Expression Quantification     Raw Counts                 NaN
# 3  Gene Expression Quantification     Raw Counts                 NaN
# 4  Gene Expression Quantification     Raw Counts                 NaN
#
#    sc_Cell Median Number Reads  sc_Cell Median Number Genes  ...  Gender  \
# 0                       9176.0                       2849.0  ...  female
# 1                      12590.0                       3571.0  ...  female
# 2                       5054.0                       1896.0  ...    male
# 3                       6722.0                       2312.5  ...    male
# 4                       6112.0                       2293.0  ...    male
#
#                 Ethnicity Vital Status HTAN Parent ID   HTAN Biospecimen ID  \
# 0  not hispanic or latino        Alive      HTA11_347  HTA11_347_2000001011
# 1  not hispanic or latino        Alive      HTA11_347  HTA11_347_2000001011
# 2  not hispanic or latino        Alive       HTA11_78   HTA11_78_2000001011
# 3  not hispanic or latino        Alive       HTA11_78   HTA11_78_2000001011
# 4  not hispanic or latino        Alive      HTA11_696  HTA11_696_2000002011
#
#   Collection Days from Index Storage Method Processing Days from Index  \
# 0                      21802          Fresh                      21802
# 1                      21802          Fresh                      21802
# 2                      24370          Fresh                      24370
# 3                      24370          Fresh                      24370
# 4                      18342          Fresh                      18342
#
#   Preservation Method Tumor Tissue Type
# 0               Fresh      Premalignant
# 1               Fresh      Premalignant
# 2               Fresh      Premalignant
# 3               Fresh      Premalignant
# 4               Fresh            Normal
#
# [5 rows x 37 columns]

# %% [markdown]
# #### obtain participant IDs is scRNA available

# %%
scCaseRace = scCaseBioDF[["HTAN Participant ID", "Race"]].drop_duplicates()
aaIDs = scCaseRace[scCaseRace["Race"]=="black or african american"]["HTAN Participant ID"].tolist()
whiteIDs = scCaseRace[scCaseRace["Race"]=="white"]["HTAN Participant ID"].tolist()
raceCounts = scCaseRace['Race'].value_counts()
raceCounts
# Out:
# white                        73
# Not Reported                 18
# black or african american    14
# Other                         1
# Name: Race, dtype: int64

# %% [markdown]
# #### african americans with scRNA and specific tumor type

# %%
scAA = scCaseBioDF[scCaseBioDF["HTAN Participant ID"].isin(aaIDs)][["HTAN Participant ID","Tumor Tissue Type"]]
scAA[["HTAN Participant ID","Tumor Tissue Type"]].drop_duplicates()
# Out:
#     HTAN Participant ID     Tumor Tissue Type
# 8              HTA11_83  Atypia - hyperplasia
# 10             HTA11_83                Normal
# 38           HTA11_5212          Premalignant
# 39           HTA11_5212                Normal
# 40           HTA11_5216  Atypia - hyperplasia
# 41           HTA11_5216                Normal
# 44           HTA11_3252                Normal
# 59           HTA11_2235                Normal
# 71           HTA11_2951          Premalignant
# 72           HTA11_2951                Normal
# 78           HTA11_2235          Premalignant
# 102          HTA11_7862          Premalignant
# 103          HTA11_7862                Normal
# 116         HTA11_10623          Premalignant
# 122          HTA11_7663          Premalignant
# 124          HTA11_7663                Normal
# 133          HTA11_7469          Premalignant
# 134          HTA11_7469                Normal
# 142          HTA11_7128          Premalignant
# 170          HTA11_6407  Atypia - hyperplasia
# 174          HTA11_6407                Normal
# 280         HTA11_12187          Premalignant
# 286          HTA11_3372  Atypia - hyperplasia

# %% [markdown]
# #### load visium metadata

# %%
visiumDF = pd.read_csv("metadata/syn51469914_10xLevel3.csv")
visiumDF["HTAN Participant ID"] = visiumDF["HTAN Data File ID"].apply(lambda X: "_".join(X.split("_")[0:2]))
visiumDF.columns = [f"visium_{X}" for X in visiumDF.columns] #164
visiumBioDF = pd.merge(visiumDF, bioQuery, left_on="visium_HTAN Data File ID", right_on="HTAN_Data_File_ID", how="inner")
visiumBioDF.head() #192
# Out:
#                                 visium_Component  \
# 0  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
# 1  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
# 2  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
# 3  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
# 4  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
#
#                                  visium_Filename visium_File Format  \
# 0       visium_level_3/6723_KL_1_barcodes.tsv.gz               gzip
# 1       visium_level_3/6723_KL_1_features.tsv.gz               gzip
# 2         visium_level_3/6723_KL_1_matrix.mtx.gz               gzip
# 3  visium_level_3/6723_KL_1_tissue_positions.csv                csv
# 4       visium_level_3/6723_KL_2_barcodes.tsv.gz               gzip
#
#   visium_HTAN Parent Biospecimen ID visium_HTAN Parent Data File ID  \
# 0           HTA11_99999971397_80384    HTA11_99999971397_8038432111
# 1           HTA11_99999971397_80384    HTA11_99999971397_8038432111
# 2           HTA11_99999971397_80384    HTA11_99999971397_8038432111
# 3           HTA11_99999971397_80384    HTA11_99999971397_8038432111
# 4           HTA11_99999971397_80384    HTA11_99999971397_8038432211
#
#        visium_HTAN Data File ID visium_Run ID visium_Visium File Type  \
# 0  HTA11_99999971397_8038433111       6723-KL                barcodes
# 1  HTA11_99999971397_8038433121       6723-KL                features
# 2  HTA11_99999971397_8038433131       6723-KL            filtered mex
# 3  HTA11_99999971397_8038433141       6723-KL        tissue_positions
# 4  HTA11_99999971397_8038433211       6723-KL                barcodes
#
#   visium_Workflow Version                               visium_Workflow Link  \
# 0       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
# 1       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
# 2       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
# 3       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
# 4       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
#
#    ...  visium_Sequencing Saturation  visium_Proportion Reads Mapped  \
# 0  ...                      0.836251                             NaN
# 1  ...                      0.836251                             NaN
# 2  ...                      0.836251                             NaN
# 3  ...                      0.836251                             NaN
# 4  ...                      0.606543                             NaN
#
#    visium_Proportion Reads Mapped to Transcriptome  \
# 0                                         0.972046
# 1                                         0.972046
# 2                                         0.972046
# 3                                         0.972046
# 4                                         0.986709
#
#    visium_Median UMI Counts per Spot  visium_entityId  \
# 0                            11356.0      syn51425743
# 1                            11356.0      syn51425744
# 2                            11356.0      syn51425745
# 3                            11356.0      syn51425746
# 4                            11038.0      syn51425747
#
#                               visium_Id                           visium_eTag  \
# 0  5ef03a71-6669-42e4-b628-426ffc5461fb  ee09f07c-fea5-4646-aa17-f982e8c68009
# 1  df5c3ac8-3e93-49be-912b-06a87505e81f  4608acf5-ee99-44b0-b792-1cfd91792835
# 2  8c8c2fb7-430d-4e49-bed6-4756d75f82a4  29460827-339b-46e7-904e-615d97a4496c
# 3  350f0a49-5ab4-4bef-8c0b-b44ad9777f9d  a6d5d102-4e53-40b8-bd51-8114a7e31cef
# 4  f8909dc9-1245-49de-861d-8fa63f39d915  07d3ca4d-b177-4caa-859e-dca729b1e54e
#
#    visium_HTAN Participant ID             HTAN_Data_File_ID  \
# 0           HTA11_99999971397  HTA11_99999971397_8038433111
# 1           HTA11_99999971397  HTA11_99999971397_8038433121
# 2           HTA11_99999971397  HTA11_99999971397_8038433131
# 3           HTA11_99999971397  HTA11_99999971397_8038433141
# 4           HTA11_99999971397  HTA11_99999971397_8038433211
#
#   HTAN_Assayed_Biospecimen_ID
# 0     HTA11_99999971397_80384
# 1     HTA11_99999971397_80384
# 2     HTA11_99999971397_80384
# 3     HTA11_99999971397_80384
# 4     HTA11_99999971397_80384
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Add biospecimen information

# %%
visiumCaseDF = pd.merge(visiumBioDF, caseBioDF, left_on="HTAN_Assayed_Biospecimen_ID", right_on="HTAN Biospecimen ID", how="inner")
visiumCaseDF.to_csv("metadata/visium_metadata.csv")
visiumCaseDF.head()
# Out:
#                                 visium_Component  \
# 0  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
# 1  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
# 2  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
# 3  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
# 4  10xVisiumSpatialTranscriptomics-RNA-seqLevel3
#
#                                  visium_Filename visium_File Format  \
# 0       visium_level_3/6723_KL_1_barcodes.tsv.gz               gzip
# 1       visium_level_3/6723_KL_1_features.tsv.gz               gzip
# 2         visium_level_3/6723_KL_1_matrix.mtx.gz               gzip
# 3  visium_level_3/6723_KL_1_tissue_positions.csv                csv
# 4       visium_level_3/6723_KL_2_barcodes.tsv.gz               gzip
#
#   visium_HTAN Parent Biospecimen ID visium_HTAN Parent Data File ID  \
# 0           HTA11_99999971397_80384    HTA11_99999971397_8038432111
# 1           HTA11_99999971397_80384    HTA11_99999971397_8038432111
# 2           HTA11_99999971397_80384    HTA11_99999971397_8038432111
# 3           HTA11_99999971397_80384    HTA11_99999971397_8038432111
# 4           HTA11_99999971397_80384    HTA11_99999971397_8038432211
#
#        visium_HTAN Data File ID visium_Run ID visium_Visium File Type  \
# 0  HTA11_99999971397_8038433111       6723-KL                barcodes
# 1  HTA11_99999971397_8038433121       6723-KL                features
# 2  HTA11_99999971397_8038433131       6723-KL            filtered mex
# 3  HTA11_99999971397_8038433141       6723-KL        tissue_positions
# 4  HTA11_99999971397_8038433211       6723-KL                barcodes
#
#   visium_Workflow Version                               visium_Workflow Link  \
# 0       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
# 1       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
# 2       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
# 3       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
# 4       spaceranger-2.0.0  https://support.10xgenomics.com/spatial-gene-e...
#
#    ...        Gender     Ethnicity  Vital Status     HTAN Parent ID  \
# 0  ...  Not Reported  Not Reported  Not Reported  HTA11_99999971397
# 1  ...  Not Reported  Not Reported  Not Reported  HTA11_99999971397
# 2  ...  Not Reported  Not Reported  Not Reported  HTA11_99999971397
# 3  ...  Not Reported  Not Reported  Not Reported  HTA11_99999971397
# 4  ...  Not Reported  Not Reported  Not Reported  HTA11_99999971397
#
#        HTAN Biospecimen ID  Collection Days from Index  Storage Method  \
# 0  HTA11_99999971397_80384                           0         unknown
# 1  HTA11_99999971397_80384                           0         unknown
# 2  HTA11_99999971397_80384                           0         unknown
# 3  HTA11_99999971397_80384                           0         unknown
# 4  HTA11_99999971397_80384                           0         unknown
#
#    Processing Days from Index Preservation Method        Tumor Tissue Type
# 0                           0             unknown  Not Otherwise Specified
# 1                           0             unknown  Not Otherwise Specified
# 2                           0             unknown  Not Otherwise Specified
# 3                           0             unknown  Not Otherwise Specified
# 4                           0             unknown  Not Otherwise Specified
#
# [5 rows x 39 columns]

# %%
visiumAA = visiumCaseDF[visiumCaseDF["HTAN Participant ID"].isin(aaIDs)]
# visiumAA["HTAN Participant ID"].drop_duplicates()
visiumAA[["HTAN Participant ID", "Tumor Tissue Type"]].drop_duplicates()
# Out:
#     HTAN Participant ID Tumor Tissue Type
# 104          HTA11_7862      Premalignant
# 112          HTA11_7663      Premalignant

# %%
visiumWhite = visiumCaseDF[visiumCaseDF["HTAN Participant ID"].isin(whiteIDs)]
visiumWhite[["HTAN Participant ID", "Tumor Tissue Type"]].drop_duplicates()
# Out:
#     HTAN Participant ID     Tumor Tissue Type
# 48           HTA11_8622          Premalignant
# 56           HTA11_1938          Premalignant
# 108         HTA11_10711          Premalignant
# 116          HTA11_6134  Atypia - hyperplasia

# %%
# B-cell: CD20, CD21, CD19
# Fibroblasts: VIM, FAP, FSP1, SMA
# T-cell: CD8, CD4, CD3, CD28
# MYE: CD68, CD80, CD86, CD206, CD163
# PLA: CD38, MUM1
# MAS: CD117
# END: CD31, CD34, VEGF

# %%
# import requests, sys

# genes = ["CD20", "CD21", "CD19", "VIM", "FAP", "FSP1", "SMA", "CD8", "CD4", "CD3", "CD28",
#          "CD68", "CD80", "CD86", "CD206", "CD163", "CD38", "MUM1", "CD117", "CD31", "CD34", "VEGF"]
 
# for gene in genes:
#   server = "https://rest.ensembl.org"
#   ext = f"/lookup/symbol/homo_sapiens/{gene}?expand=1"
  
#   r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
#   if not r.ok:
#     r.raise_for_status()
#     sys.exit()
  
#   decoded = r.json()
#   print(repr(decoded))
#   break
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[265], line 13
#      10 r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
#      12 if not r.ok:
# ---> 13   r.raise_for_status()
#      14   sys.exit()
#      16 decoded = r.json()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://rest.ensembl.org/lookup/symbol/homo_sapiens/CD20?expand=1
